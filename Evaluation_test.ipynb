# %% [markdown]
# ## Evaluation and Experiment

# %%
from multiAgent_evaluate import *

# %% [markdown]
# ## Evaluation Output of our Freamework

# %%
import json

def analyze_debate_json(json_path):
    with open(json_path, "r") as f:
        results = json.load(f)

    total = len(results)
    correct = 0
    partial = 0
    pro_correct = 0
    con_correct = 0
    pro_win = 0
    con_win = 0
    con_chosen_and_correct = 0

    con_correct_ids = []
    con_chosen_ids = []

    for qid, item in results.items():
        gt = item.get("ground_truth", "").strip()

        # Pro / Con Answers
        if "rounds" in item and len(item["rounds"]) > 0:
            pro = item["rounds"][0].get("pro_answer", "").strip()
            con = item["rounds"][0].get("con_answer", "").strip()
        else:
            pro = item.get("pro_answer", "").strip()
            con = item.get("con_answer", "").strip()

        # Consensus Answer
        consensus = (
            item.get("final_answer", "").strip()
            if "final_answer" in item else
            item.get("consensus_answer", "").strip()
        )

        if pro == gt:
            pro_correct += 1
        if con == gt:
            con_correct += 1
            con_correct_ids.append(qid)
        if gt in [pro, con]:
            partial += 1
        if consensus == gt:
            correct += 1
        if consensus == pro:
            pro_win += 1
        elif consensus == con:
            con_win += 1
            con_chosen_ids.append(qid)
            if con == gt:
                con_chosen_and_correct += 1

    con_union_ids = sorted(set(con_correct_ids + con_chosen_ids))

    print("=== 📊 Evaluation Summary ===")
    print(f"Total Cases Analyzed: {total}")
    print(f"✅ Consensus Correct: {correct}/{total} = {correct/total:.2%}")
    print(f"🔹 Pro or Con got GT: {partial}/{total} = {partial/total:.2%}")
    print(f"📈 Pro Answered Correctly: {pro_correct}/{total} = {pro_correct/total:.2%}")
    print(f"📉 Con Answered Correctly: {con_correct}/{total} = {con_correct/total:.2%}")
    print(f"🧠 Consensus chose Pro: {pro_win} times")
    print(f"🧠 Consensus chose Con: {con_win} times")
    print(f"🎯 Chose Con AND Correct: {con_chosen_and_correct} times")

    return {
        "con_correct_ids": con_correct_ids,
        "con_chosen_ids": con_chosen_ids,
        "union_ids": con_union_ids
    }

# %%
analyze_debate_json("output_0_315.json")
# Out:
# === 📊 Evaluation Summary ===
# Total Cases Analyzed: 315
# ✅ Consensus Correct: 275/315 = 87.30%
# 🔹 Pro or Con got GT: 290/315 = 92.06%
# 📈 Pro Answered Correctly: 261/315 = 82.86%
# 📉 Con Answered Correctly: 29/315 = 9.21%
# 🧠 Consensus chose Pro: 289 times
# 🧠 Consensus chose Con: 22 times
# 🎯 Chose Con AND Correct: 18 times
# {'con_correct_ids': ['0000',
#   '0001',
#   '0009',
#   '0023',
#   '0034',
#   '0044',
#   '0045',
#   '0049',
#   '0064',
#   '0072',
#   '0112',
#   '0117',
#   '0172',
#   '0184',
#   '0188',
#   '0208',
#   '0211',
#   '0231',
#   '0238',
#   '0242',
#   '0260',
#   '0267',
#   '0278',
#   '0283',
#   '0285',
#   '0300',
#   '0100',
#   '0234',
#   '0241'],
#  'con_chosen_ids': ['0001',
#   '0034',
#   '0045',
#   '0049',
#   '0064',
#   '0117',
#   '0160',
#   '0172',
#   '0184',
#   '0188',
#   '0194',
#   '0208',
#   '0211',
#   '0231',
#   '0238',
#   '0260',
#   '0267',
#   '0273',
#   '0285',
#   '0290',
#   '0300',
#   '0241'],
#  'union_ids': ['0000',
#   '0001',
#   '0009',
#   '0023',
#   '0034',
#   '0044',
#   '0045',
#   '0049',
#   '0064',
#   '0072',
#   '0100',
#   '0112',
#   '0117',
#   '0160',
#   '0172',
#   '0184',
#   '0188',
#   '0194',
#   '0208',
#   '0211',
#   '0231',
#   '0234',
#   '0238',
#   '0241',
#   '0242',
#   '0260',
#   '0267',
#   '0273',
#   '0278',
#   '0283',
#   '0285',
#   '0290',
#   '0300']}

# %% [markdown]
# ## Bias Test

# %%
results1 = run_all_benchmark_cases(
    json_path="",
    pro_fn=generate_first_round_response_pro,
    con_fn=generate_first_round_response_con,
    debate_fn=generate_agent_response,
    consensus_fn=generate_consensus,
    start_index=315, 
    max_cases=100 ,   
    save_path="result_316.json"
)
# Out:
# 🚀 Running Case 0315
# ✅ Saved result for 0315
#
# 🚀 Running Case 0316
# ✅ Saved result for 0316
#
# 🚀 Running Case 0317
# ✅ Saved result for 0317
#
# 🚀 Running Case 0318
# ✅ Saved result for 0318
#
# 🚀 Running Case 0319
# ✅ Saved result for 0319
#
# 🚀 Running Case 0320
# ✅ Saved result for 0320
#
# 🚀 Running Case 0321
# ✅ Saved result for 0321
#
# 🚀 Running Case 0322
# ✅ Saved result for 0322
#
# 🚀 Running Case 0323
# ✅ Saved result for 0323
#
# 🚀 Running Case 0324
# ✅ Saved result for 0324
#
# 🚀 Running Case 0325
# ✅ Saved result for 0325
#
# 🚀 Running Case 0326
# ✅ Saved result for 0326
#
# 🚀 Running Case 0327
# ✅ Saved result for 0327
#
# 🚀 Running Case 0328
# ✅ Saved result for 0328
#
# 🚀 Running Case 0329
# ✅ Saved result for 0329
#
# 🚀 Running Case 0330
# ✅ Saved result for 0330
#
# 🚀 Running Case 0331
# ✅ Saved result for 0331
#
# 🚀 Running Case 0332
# ✅ Saved result for 0332
#
# 🚀 Running Case 0333
# ✅ Saved result for 0333
#
# 🚀 Running Case 0334
# ✅ Saved result for 0334
#
# 🚀 Running Case 0335
# ✅ Saved result for 0335
#
# 🚀 Running Case 0336
# ✅ Saved result for 0336
#
# 🚀 Running Case 0337
# ✅ Saved result for 0337
#
# 🚀 Running Case 0338
# ✅ Saved result for 0338
#
# 🚀 Running Case 0339
# ✅ Saved result for 0339
#
# 🚀 Running Case 0340
# ✅ Saved result for 0340
#
# 🚀 Running Case 0341
# ✅ Saved result for 0341
#
# 🚀 Running Case 0342
# ✅ Saved result for 0342
#
# 🚀 Running Case 0343
# ✅ Saved result for 0343
#
# 🚀 Running Case 0344
# ✅ Saved result for 0344
#
# 🚀 Running Case 0345
# ✅ Saved result for 0345
#
# 🚀 Running Case 0346
# ✅ Saved result for 0346
#
# 🚀 Running Case 0347
# ✅ Saved result for 0347
#
# 🚀 Running Case 0348
# ✅ Saved result for 0348
#
# 🚀 Running Case 0349
# ✅ Saved result for 0349
#
# 🚀 Running Case 0350
# ✅ Saved result for 0350
#
# 🚀 Running Case 0351
# ✅ Saved result for 0351
#
# 🚀 Running Case 0352
# ✅ Saved result for 0352
#
# 🚀 Running Case 0353
# ✅ Saved result for 0353
#
# 🚀 Running Case 0354
# ✅ Saved result for 0354
#
# 🚀 Running Case 0355
# ✅ Saved result for 0355
#
# 🚀 Running Case 0356
# ✅ Saved result for 0356
#
# 🚀 Running Case 0357
# ✅ Saved result for 0357
#
# 🚀 Running Case 0358
# ✅ Saved result for 0358
#
# 🚀 Running Case 0359
# ✅ Saved result for 0359
#
# 🚀 Running Case 0360
# ✅ Saved result for 0360
#
# 🚀 Running Case 0361
# ✅ Saved result for 0361
#
# 🚀 Running Case 0362
# ✅ Saved result for 0362
#
# 🚀 Running Case 0363
# ✅ Saved result for 0363
#
# 🚀 Running Case 0364
# ✅ Saved result for 0364
#
# 🚀 Running Case 0365
# ✅ Saved result for 0365
#
# 🚀 Running Case 0366
# ✅ Saved result for 0366
#
# 🚀 Running Case 0367
# ✅ Saved result for 0367
#
# 🚀 Running Case 0368
# ✅ Saved result for 0368
#
# 🚀 Running Case 0369
# ✅ Saved result for 0369
#
# 🚀 Running Case 0370
# ✅ Saved result for 0370
#
# 🚀 Running Case 0371
# ✅ Saved result for 0371
#
# 🚀 Running Case 0372
# ✅ Saved result for 0372
#
# 🚀 Running Case 0373
# ✅ Saved result for 0373
#
# 🚀 Running Case 0374
# ✅ Saved result for 0374
#
# 🚀 Running Case 0375
# ✅ Saved result for 0375
#
# 🚀 Running Case 0376
# ✅ Saved result for 0376
#
# 🚀 Running Case 0377
# ✅ Saved result for 0377
#
# 🚀 Running Case 0378
# ✅ Saved result for 0378
#
# 🚀 Running Case 0379
# ✅ Saved result for 0379
#
# 🚀 Running Case 0380
# ✅ Saved result for 0380
#
# 🚀 Running Case 0381
# ✅ Saved result for 0381
#
# 🚀 Running Case 0382
# ✅ Saved result for 0382
#
# 🚀 Running Case 0383
# ✅ Saved result for 0383
#
# 🚀 Running Case 0384
# ✅ Saved result for 0384
#
# 🚀 Running Case 0385
# ✅ Saved result for 0385
#
# 🚀 Running Case 0386
# ✅ Saved result for 0386
#
# 🚀 Running Case 0387
# ✅ Saved result for 0387
#
# 🚀 Running Case 0388
# ✅ Saved result for 0388
#
# 🚀 Running Case 0389
# ✅ Saved result for 0389
#
# 🚀 Running Case 0390
# ✅ Saved result for 0390
#
# 🚀 Running Case 0391
# ✅ Saved result for 0391
#
# 🚀 Running Case 0392
# ✅ Saved result for 0392
#
# 🚀 Running Case 0393
# ✅ Saved result for 0393
#
# 🚀 Running Case 0394
# ✅ Saved result for 0394
#
# 🚀 Running Case 0395
# ✅ Saved result for 0395
#
# 🚀 Running Case 0396
# ✅ Saved result for 0396
#
# 🚀 Running Case 0397
# ✅ Saved result for 0397
#
# 🚀 Running Case 0398
# ✅ Saved result for 0398
#
# 🚀 Running Case 0399
# ✅ Saved result for 0399
#
# 🚀 Running Case 0400
# ✅ Saved result for 0400
#
# 🚀 Running Case 0401
# ✅ Saved result for 0401
#
# 🚀 Running Case 0402
# ✅ Saved result for 0402
#
# 🚀 Running Case 0403
# ✅ Saved result for 0403
#
# 🚀 Running Case 0404
# ✅ Saved result for 0404
#
# 🚀 Running Case 0405
# ✅ Saved result for 0405
#
# 🚀 Running Case 0406
# ✅ Saved result for 0406
#
# 🚀 Running Case 0407
# ✅ Saved result for 0407
#
# 🚀 Running Case 0408
# ✅ Saved result for 0408
#
# 🚀 Running Case 0409
# ✅ Saved result for 0409
#
# 🚀 Running Case 0410
# ✅ Saved result for 0410
#
# 🚀 Running Case 0411
# ✅ Saved result for 0411
#
# 🚀 Running Case 0412
# ✅ Saved result for 0412
#
# 🚀 Running Case 0413
# ✅ Saved result for 0413
#
# 🚀 Running Case 0414
# ✅ Saved result for 0414
#
# 🎉 Completed 100 new cases.

# %%
import json

def evaluate_saved_results(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)

    total = len(data)
    consensus_correct = 0
    pro_correct = 0
    con_correct = 0
    either_correct = 0
    consensus_pro = 0
    consensus_con = 0
    con_chosen_and_correct = 0

    for qid, entry in data.items():
        gt = entry.get("ground_truth", "").strip()
        pro = entry.get("pro_answer", "").strip()
        con = entry.get("con_answer", "").strip()
        consensus = entry.get("consensus_answer", "").strip()

        if pro == gt:
            pro_correct += 1
        if con == gt:
            con_correct += 1
        if gt in [pro, con]:
            either_correct += 1
        if consensus == gt:
            consensus_correct += 1
        if consensus == pro:
            consensus_pro += 1
        if consensus == con:
            consensus_con += 1
            if con == gt:
                con_chosen_and_correct += 1

    print("=== 📊 Evaluation Summary ===")
    print(f"Total Cases Analyzed: {total}")
    print(f"✅ Consensus Correct: {consensus_correct}/{total} = {consensus_correct/total:.2%}")
    print(f"🔹 Pro or Con got GT: {either_correct}/{total} = {either_correct/total:.2%}")
    print(f"📈 Pro Answered Correctly: {pro_correct}/{total} = {pro_correct/total:.2%}")
    print(f"📉 Con Answered Correctly: {con_correct}/{total} = {con_correct/total:.2%}")
    print(f"🧠 Consensus chose Pro: {consensus_pro} times")
    print(f"🧠 Consensus chose Con: {consensus_con} times")
    print(f"🎯 Chose Con AND Correct: {con_chosen_and_correct} times")

# 用法示例
evaluate_saved_results("result_316.json")
# Out:
# === 📊 Evaluation Summary ===
# Total Cases Analyzed: 100
# ✅ Consensus Correct: 85/100 = 85.00%
# 🔹 Pro or Con got GT: 97/100 = 97.00%
# 📈 Pro Answered Correctly: 85/100 = 85.00%
# 📉 Con Answered Correctly: 14/100 = 14.00%
# 🧠 Consensus chose Pro: 88 times
# 🧠 Consensus chose Con: 13 times
# 🎯 Chose Con AND Correct: 7 times
